# %%
import random
import string
import bcrypt
import pandas as pd

# %%
def hash_pass(password: str) -> str:
    """
    
    Hash a password with bcrypt. Default salt is set to 10.
    
    """
    
    salt = bcrypt.gensalt(10)
    hashed = bcrypt.hashpw(password.encode(), salt)
    
    return hashed.decode()

# %%
def random_password(lenght: int = 10) -> str:
    """
    
    Generate random passwords.
    
    """
    
    all_chars = string.ascii_lowercase + string.ascii_uppercase + string.digits
    
    password = "".join(random.sample(all_chars, lenght))
    
    return password

# %%
random_password(10)
# Out:
# 'hWru9k5QzC'

# %%
hash_pass('+=y*05Izew')
# Out:
# '$2b$10$qOoxHbm42G4ad6y6k7K8FueWq6LLRgtEp18HjviLQivAN1gHHQBCO'

# %%
admins = pd.read_csv("../data-version2/final_version/users_pg.csv")
admins.head()
# Out:
#    id  email passwordHashed  registrationDate             role  \
# 0   0    NaN          admin               NaN  UNIVERSITYADMIN
# 1   1    NaN          admin               NaN  UNIVERSITYADMIN
# 2   2    NaN          admin               NaN  UNIVERSITYADMIN
# 3   3    NaN          admin               NaN  UNIVERSITYADMIN
# 4   4    NaN          admin               NaN  UNIVERSITYADMIN
#
#                                    username  emailVerified
# 0                    KaitsevueeAkadeemia172          False
# 1             FiaUFundaueueoInstitutoDe1168          False
# 2              BostonSchoolOfSocialWork4076          False
# 3  GeorgeWashingtonCollegeOfProfessional645          False
# 4         NewJerseyInstituteOfTechnology694          False

# %%
# lets create password for each admin account

admin_accounts = admins[["id", "username"]]
admin_accounts.head()
# Out:
#    id                                  username
# 0   0                    KaitsevueeAkadeemia172
# 1   1             FiaUFundaueueoInstitutoDe1168
# 2   2              BostonSchoolOfSocialWork4076
# 3   3  GeorgeWashingtonCollegeOfProfessional645
# 4   4         NewJerseyInstituteOfTechnology694

# %%
def password_for_admin(row: pd.Series) -> pd.Series:
    """
    
    Generate a random password and convert hash then set to admin user account.
    
    """
    
    admin_id = row["id"]
    password = random_password()
    hashed   = hash_pass(password)
    
    row["password"]       = password
    row["passwordHashed"] = hashed 
    
    if admin_id % 100 == 0: print(f"Admin {admin_id}. done...")
    
    return row

# %%
admin_accounts_final = admin_accounts.apply(password_for_admin, axis=1)
# Out:
# Admin 0. done...
# Admin 100. done...
# Admin 200. done...
# Admin 300. done...
# Admin 400. done...
# Admin 500. done...
# Admin 600. done...
# Admin 700. done...
# Admin 800. done...
# Admin 900. done...
# Admin 1000. done...
# Admin 1100. done...
# Admin 1200. done...
# Admin 1300. done...
# Admin 1400. done...
# Admin 1500. done...
# Admin 1600. done...
# Admin 1700. done...
# Admin 1800. done...
# Admin 1900. done...
# Admin 2000. done...
# Admin 2100. done...
# Admin 2200. done...
# Admin 2300. done...
# Admin 2400. done...
# Admin 2500. done...
# Admin 2600. done...
# Admin 2700. done...
# Admin 2800. done...
# Admin 2900. done...
# Admin 3000. done...
# Admin 3100. done...
# Admin 3200. done...
# Admin 3300. done...
# Admin 3400. done...
# Admin 3500. done...
# Admin 3600. done...
# Admin 3700. done...
# Admin 3800. done...
# Admin 3900. done...
# Admin 4000. done...
# Admin 4100. done...
# Admin 4200. done...
# Admin 4300. done...

# %%
admin_accounts_final.head()
# Out:
#    id                                  username    password  \
# 0   0                    KaitsevueeAkadeemia172  4vc8QVqWyU
# 1   1             FiaUFundaueueoInstitutoDe1168  Bc53S0goue
# 2   2              BostonSchoolOfSocialWork4076  6qlg1EfPAH
# 3   3  GeorgeWashingtonCollegeOfProfessional645  OtvfQLn8uw
# 4   4         NewJerseyInstituteOfTechnology694  lvR9FU3Mfn
#
#                                       passwordHashed
# 0  $2b$10$2AQOUOnd9dE/r9d4alJyNeUXqMlwq72BfXW6Xip...
# 1  $2b$10$mRCMLl2QKQ1z7KIn2UzRNeJwitpYzTY/sm0i4wZ...
# 2  $2b$10$fhgdeeztYYCqLIIACPLAg.VXx6GfAGjItKpIN.G...
# 3  $2b$10$EqcfTpJAadlGQJKNw3lnmOmA5mFd.uAIfg4/Jfj...
# 4  $2b$10$fXCsp6BLl.PDPuOvBUP49.ex7fVZHyBaVUUtrOM...

# %%
admins["passwordHashed"] = admin_accounts_final["passwordHashed"]
admins.head()
# Out:
#    id  email                                     passwordHashed  \
# 0   0    NaN  $2b$10$2AQOUOnd9dE/r9d4alJyNeUXqMlwq72BfXW6Xip...
# 1   1    NaN  $2b$10$mRCMLl2QKQ1z7KIn2UzRNeJwitpYzTY/sm0i4wZ...
# 2   2    NaN  $2b$10$fhgdeeztYYCqLIIACPLAg.VXx6GfAGjItKpIN.G...
# 3   3    NaN  $2b$10$EqcfTpJAadlGQJKNw3lnmOmA5mFd.uAIfg4/Jfj...
# 4   4    NaN  $2b$10$fXCsp6BLl.PDPuOvBUP49.ex7fVZHyBaVUUtrOM...
#
#    registrationDate             role  \
# 0               NaN  UNIVERSITYADMIN
# 1               NaN  UNIVERSITYADMIN
# 2               NaN  UNIVERSITYADMIN
# 3               NaN  UNIVERSITYADMIN
# 4               NaN  UNIVERSITYADMIN
#
#                                    username  emailVerified
# 0                    KaitsevueeAkadeemia172          False
# 1             FiaUFundaueueoInstitutoDe1168          False
# 2              BostonSchoolOfSocialWork4076          False
# 3  GeorgeWashingtonCollegeOfProfessional645          False
# 4         NewJerseyInstituteOfTechnology694          False

# %%
admins.fillna("", inplace=True)
admins.head()
# Out:
#    id email                                     passwordHashed  \
# 0   0        $2b$10$2AQOUOnd9dE/r9d4alJyNeUXqMlwq72BfXW6Xip...
# 1   1        $2b$10$mRCMLl2QKQ1z7KIn2UzRNeJwitpYzTY/sm0i4wZ...
# 2   2        $2b$10$fhgdeeztYYCqLIIACPLAg.VXx6GfAGjItKpIN.G...
# 3   3        $2b$10$EqcfTpJAadlGQJKNw3lnmOmA5mFd.uAIfg4/Jfj...
# 4   4        $2b$10$fXCsp6BLl.PDPuOvBUP49.ex7fVZHyBaVUUtrOM...
#
#   registrationDate             role                                  username  \
# 0                   UNIVERSITYADMIN                    KaitsevueeAkadeemia172
# 1                   UNIVERSITYADMIN             FiaUFundaueueoInstitutoDe1168
# 2                   UNIVERSITYADMIN              BostonSchoolOfSocialWork4076
# 3                   UNIVERSITYADMIN  GeorgeWashingtonCollegeOfProfessional645
# 4                   UNIVERSITYADMIN         NewJerseyInstituteOfTechnology694
#
#    emailVerified
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False

# %%
admins.to_csv("../data-version2/final_version/final_admin_users_pg.csv", index=False)

# %%
admin_accounts_final.drop(["passwordHashed"], axis=1, inplace=True)

# %%
admin_accounts_final.head()
# Out:
#    id                                  username    password
# 0   0                    KaitsevueeAkadeemia172  4vc8QVqWyU
# 1   1             FiaUFundaueueoInstitutoDe1168  Bc53S0goue
# 2   2              BostonSchoolOfSocialWork4076  6qlg1EfPAH
# 3   3  GeorgeWashingtonCollegeOfProfessional645  OtvfQLn8uw
# 4   4         NewJerseyInstituteOfTechnology694  lvR9FU3Mfn

# %%
admin_accounts_final.to_csv("./admin_user_accounts_info_pg.csv", index=False)
