# %%
import pandas as pd

# %%
countries = pd.read_csv("../data-version2/raw/cities/country-quality-of-indexes.csv")
countries.head()
# Out:
#          country Purchasing Power Index Purchasing Power Index Category  \
# 0    Afghanistan                  22.41                        Very Low
# 1  Aland Islands                  99.96                            High
# 2        Albania                  24.62                        Very Low
# 3       Alderney                      ?                             NaN
# 4        Algeria                  24.80                        Very Low
#
#   Safety Index Safety Index Category Health Care Index  \
# 0        22.71                   Low             26.98
# 1        77.81                  High             87.27
# 2        54.30              Moderate             50.54
# 3        91.67             Very High            100.00
# 4        45.92              Moderate             52.74
#
#   Health Care Index Category Climate Index Climate Index Category  \
# 0                        Low             ?                    NaN
# 1                  Very High             ?                    NaN
# 2                   Moderate         86.43              Very High
# 3                  Very High             ?                    NaN
# 4                   Moderate         94.82              Very High
#
#   Cost of Living Index Cost of Living Index Category  \
# 0                22.17                      Very Low
# 1                73.13                          High
# 2                35.81                      Very Low
# 3                    ?                           NaN
# 4                26.85                      Very Low
#
#   Property Price to Income Ratio Property Price to Income Ratio Category  \
# 0                          14.03                                    High
# 1                           4.36                                Very Low
# 2                          17.11                               Very High
# 3                              ?                                     NaN
# 4                          17.71                               Very High
#
#   Traffic Commute Time Index Traffic Commute Time Index Category  \
# 0                      56.17                           Very High
# 1                      19.05                            Very Low
# 2                      38.21                            Moderate
# 3                          ?                                 NaN
# 4                      48.89                                High
#
#   Pollution Index Pollution Index Category Quality of Life Index  \
# 0           86.83                Very High                     ?
# 1           15.00                 Very Low                     ?
# 2           78.78                     High                 93.71
# 3            3.45                 Very Low                     ?
# 4           65.00                     High                 97.42
#
#   Quality of Life Index Category
# 0                            NaN
# 1                            NaN
# 2                       Very Low
# 3                            NaN
# 4                       Very Low

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 19 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  234 non-null    object
#  1   Purchasing Power Index                   234 non-null    object
#  2   Purchasing Power Index Category          181 non-null    object
#  3   Safety Index                             234 non-null    object
#  4   Safety Index Category                    232 non-null    object
#  5   Health Care Index                        234 non-null    object
#  6   Health Care Index Category               212 non-null    object
#  7   Climate Index                            234 non-null    object
#  8   Climate Index Category                   125 non-null    object
#  9   Cost of Living Index                     234 non-null    object
#  10  Cost of Living Index Category            181 non-null    object
#  11  Property Price to Income Ratio           234 non-null    object
#  12  Property Price to Income Ratio Category  196 non-null    object
#  13  Traffic Commute Time Index               234 non-null    object
#  14  Traffic Commute Time Index Category      200 non-null    object
#  15  Pollution Index                          234 non-null    object
#  16  Pollution Index Category                 215 non-null    object
#  17  Quality of Life Index                    234 non-null    object
#  18  Quality of Life Index Category           125 non-null    object
# dtypes: object(19)
# memory usage: 34.9+ KB

# %%
cities = pd.read_csv("../data-version2/raw/cities/city-quality-of-indexes.csv")
cities.head()
# Out:
#           city  country Purchasing Power Index  \
# 0  Constantine  Algeria                  24.92
# 1        Jijel  Algeria                      ?
# 2         Oran  Algeria                  21.01
# 3        Setif  Algeria                  20.84
# 4       Skikda  Algeria                      ?
#
#   Purchasing Power Index Category  Safety Index Safety Index Category  \
# 0                        Very Low         55.32              Moderate
# 1                             NaN         54.66              Moderate
# 2                        Very Low         45.78              Moderate
# 3                        Very Low         39.92                   Low
# 4                             NaN         86.76             Very High
#
#    Health Care Index Health Care Index Category Climate Index  \
# 0              40.28                   Moderate         84.71
# 1              43.06                   Moderate             ?
# 2              55.32                   Moderate         96.35
# 3              59.26                   Moderate         80.17
# 4              22.22                        Low             ?
#
#   Climate Index Category Cost of Living Index Cost of Living Index Category  \
# 0              Very High                27.61                      Very Low
# 1                    NaN                    ?                           NaN
# 2              Very High                28.43                      Very Low
# 3              Very High                26.38                      Very Low
# 4                    NaN                    ?                           NaN
#
#   Property Price to Income Ratio Property Price to Income Ratio Category  \
# 0                          14.00                                    High
# 1                          13.02                                    High
# 2                          22.22                               Very High
# 3                          94.89                               Very High
# 4                              ?                                     NaN
#
#    Traffic Commute Time Index Traffic Commute Time Index Category  \
# 0                        55.5                           Very High
# 1                        20.0                            Very Low
# 2                       105.0                           Very High
# 3                        13.5                            Very Low
# 4                         3.0                            Very Low
#
#    Pollution Index Pollution Index Category Quality of Life Index  \
# 0            68.82                     High                 91.58
# 1            53.45                 Moderate                     ?
# 2            58.87                 Moderate                 68.73
# 3            72.41                     High                 26.16
# 4           117.24                Very High                     ?
#
#   Quality of Life Index Category
# 0                       Very Low
# 1                            NaN
# 2                       Very Low
# 3                       Very Low
# 4                            NaN

# %%
cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283 entries, 0 to 282
# Data columns (total 20 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   city                                     283 non-null    object
#  1   country                                  283 non-null    object
#  2   Purchasing Power Index                   283 non-null    object
#  3   Purchasing Power Index Category          100 non-null    object
#  4   Safety Index                             283 non-null    float64
#  5   Safety Index Category                    283 non-null    object
#  6   Health Care Index                        283 non-null    float64
#  7   Health Care Index Category               283 non-null    object
#  8   Climate Index                            283 non-null    object
#  9   Climate Index Category                   211 non-null    object
#  10  Cost of Living Index                     283 non-null    object
#  11  Cost of Living Index Category            100 non-null    object
#  12  Property Price to Income Ratio           283 non-null    object
#  13  Property Price to Income Ratio Category  216 non-null    object
#  14  Traffic Commute Time Index               283 non-null    float64
#  15  Traffic Commute Time Index Category      283 non-null    object
#  16  Pollution Index                          283 non-null    float64
#  17  Pollution Index Category                 283 non-null    object
#  18  Quality of Life Index                    283 non-null    object
#  19  Quality of Life Index Category           79 non-null     object
# dtypes: float64(4), object(16)
# memory usage: 44.3+ KB

# %%
cities[cities["country"] == "Canada"]
# Out:
#                city country Purchasing Power Index  \
# 42          Airdrie  Canada                      ?
# 43           Kanata  Canada                      ?
# 44      Maple Ridge  Canada                  85.53
# 45           Milton  Canada                      ?
# 46        Nelson BC  Canada                      ?
# 47  North Vancouver  Canada                 119.43
# 48          Okotoks  Canada                      ?
# 49    Prince Albert  Canada                      ?
# 50        Woodstock  Canada                      ?
#
#    Purchasing Power Index Category  Safety Index Safety Index Category  \
# 42                             NaN         62.06                  High
# 43                             NaN         24.37                   Low
# 44                            High         49.30              Moderate
# 45                             NaN         58.53              Moderate
# 46                             NaN         66.76                  High
# 47                       Very High         79.47                  High
# 48                             NaN         83.82             Very High
# 49                             NaN         37.35                   Low
# 50                             NaN         44.33              Moderate
#
#     Health Care Index Health Care Index Category Climate Index  \
# 42              87.50                  Very High             ?
# 43              69.44                       High         45.15
# 44              75.56                       High         34.74
# 45              90.74                  Very High         53.31
# 46              80.56                  Very High         71.69
# 47              75.23                       High         91.15
# 48              88.89                  Very High             ?
# 49              83.33                  Very High          9.08
# 50              66.67                       High         55.89
#
#    Climate Index Category Cost of Living Index Cost of Living Index Category  \
# 42                    NaN                    ?                           NaN
# 43               Moderate                    ?                           NaN
# 44               Moderate                73.26                          High
# 45               Moderate                    ?                           NaN
# 46                   High                    ?                           NaN
# 47              Very High                68.34                      Moderate
# 48                    NaN                    ?                           NaN
# 49                    Low                    ?                           NaN
# 50               Moderate                    ?                           NaN
#
#    Property Price to Income Ratio Property Price to Income Ratio Category  \
# 42                           5.17                                     Low
# 43                           6.24                                     Low
# 44                           6.42                                     Low
# 45                           4.23                                Very Low
# 46                           6.60                                     Low
# 47                           8.91                                Moderate
# 48                              ?                                     NaN
# 49                              ?                                     NaN
# 50                           5.07                                     Low
#
#     Traffic Commute Time Index Traffic Commute Time Index Category  \
# 42                       31.00                                 Low
# 43                        7.00                            Very Low
# 44                       37.00                            Moderate
# 45                       30.00                                 Low
# 46                       26.67                            Very Low
# 47                       49.62                                High
# 48                       30.00                                 Low
# 49                       15.00                            Very Low
# 50                        8.00                            Very Low
#
#     Pollution Index Pollution Index Category Quality of Life Index  \
# 42            43.97                 Moderate                     ?
# 43             3.45                 Very Low                     ?
# 44            41.38                 Moderate                140.83
# 45            26.01                      Low                     ?
# 46            12.84                 Very Low                     ?
# 47            16.94                 Very Low                196.13
# 48            10.34                 Very Low                     ?
# 49            33.62                      Low                     ?
# 50            53.45                 Moderate                     ?
#
#    Quality of Life Index Category
# 42                            NaN
# 43                            NaN
# 44                       Moderate
# 45                            NaN
# 46                            NaN
# 47                      Very High
# 48                            NaN
# 49                            NaN
# 50                            NaN
